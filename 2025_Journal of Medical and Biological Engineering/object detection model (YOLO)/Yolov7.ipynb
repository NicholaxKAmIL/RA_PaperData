# %% [markdown]
# <h3>重現前作</h3>

# %%
# !./darknet detector train ../_RA/Darknet/data/bones/obj.data ../_RA/Darknet/data/bones/v4_RA_rework.cfg -clear -map -dont_show

# %% [markdown]
# <h5>計算anchor</h5>

# %%
# !./darknet detector calc_anchors ../_RA/Darknet/data/bones/obj.data -num_of_clusters 9 -width 640 -height 640 -show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.9.2, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.5.1
#
#  num_of_clusters = 9, width = 640, height = 640
#  read labels from 915 images
#  loaded 	 image: 915 	 box: 26967 11174	 image: 577 	 box: 171113733
#  all loaded.
#
#  calculating k-means++ ...
#
#  iterations = 87
#
#
# counters_per_class = 26967
#
#  avg IoU = 81.99 %
#
# Saving anchors to the file: anchors.txt
# anchors =  18, 23,  26, 19,  27, 29,  38, 23,  28, 42,  36, 33,  40, 45,  42, 60,  70, 38
# Unable to init server: Could not connect: Connection refused
# terminate called after throwing an instance of 'cv::Exception'
#   what():  OpenCV(4.5.1) ../modules/highgui/src/window_gtk.cpp:624: error: (-2:Unspecified error) Can't initialize GTK backend in function 'cvInitSystem'

# %% [markdown]
# <h1>YOLOV7相關部分</h1>

# %%
./darknet detector train ../_RA/Darknet/data/bones/obj.data ./cfg_RA/yolov7.cfg ./backup/yolov7_10000.weights -dont_show

# %%
./darknet detector train ../_RA/Darknet/data/bones/objNoWL.data ./cfg_RA/yolov7.cfg -dont_show

# %%
# Out:
# '1Ur3rEWx4Aroxh5FrFvtxwOXSTfdPw16Y?usp=sharing'     docker-compose.yml
# '1Ur3rEWx4Aroxh5FrFvtxwOXSTfdPw16Y?usp=sharing.1'   Dockerfile.cpu
# '1Ur3rEWx4Aroxh5FrFvtxwOXSTfdPw16Y?usp=sharing.2'   Dockerfile.gpu
# '1Ur3rEWx4Aroxh5FrFvtxwOXSTfdPw16Y?usp=sharing.3'   Face_Mask_data
# '1Ur3rEWx4Aroxh5FrFvtxwOXSTfdPw16Y?usp=sharing.4'   image_yolov3.sh
#  3rdparty					    image_yolov4.sh
#  anchors.txt					    include
#  backup						    json_mjpeg_streams.sh
#  build						    libdarknet.so
#  build.ps1					    LICENSE
#  cfg						    Makefile
#  cfg_RA						    net_cam_v3.sh
#  chart.png					    net_cam_v4.sh
#  chart_v4_RA_rework.png				    _Newyolov7.ipynb
#  chart_yolov4-bone-JustWL.png			    obj
#  chart_yolov4-bone-MoButNoIOU.png		    package.xml
#  chart_yolov4-bone-NoMoButIOU.png		    predictions.jpg
#  chart_yolov4-bone-NoMoButNoIOU.png		    README.md
#  chart_yolov7.png				    results
#  cloud.png					    Rivision重現.ipynb
#  cmake						    scripts
#  CMakeLists.txt					    src
# ...

# %%
# !./darknet detector train ./cfg_RA/JSN/obj.data ./cfg_RA/JSN/yolov7_RA_Full_Origin_JSN.cfg -clear -map -dont_show

# %% [markdown]
# <h3>Results</h3>

# %%
# !./darknet detector map ../_RA/Darknet/data/bones/objNoWL.data ./cfg_RA/yolov7.cfg ./backup/yolov7_Origin//yolov7_60000.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 12020 (12000)
# ...
# , cuDNN: 8.9.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 860, cudnn_half = 1, GPU: NVIDIA RTXA6000-16C
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       3 x 3/ 1    304 x 304 x  64 ->  304 x 304 x  64 6.814 BF
#    3 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    4 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    5 route  3 		                           ->  152 x 152 x 128
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
# ...
